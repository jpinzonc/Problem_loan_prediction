# %% [markdown]
# # Problem loan prediction 2017 - Lending Club
# ## Testing model with 2016 Data

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import numpy as np
import matplotlib.pyplot as pl
import datetime
# %matplotlib inline
l_encoder = LabelEncoder()

# %% [markdown]
# ## Uploading and cleaning the data

# %%
# Uploading data from 2016
data_2016 = pd.read_csv('data_files/LoanStats_2016Q4.csv', skiprows=1, low_memory=False)

# %%
print (data_2016.shape)
print('HEAD')
display(data_2016.head())
print('\n TAIL')
display(data_2016.tail())
# Out:
# (103548, 145)
# HEAD
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN     5000.0       5000.0           5000.0   36 months
# 1  NaN        NaN    13000.0      13000.0          13000.0   36 months
# 2  NaN        NaN    18000.0      18000.0          18000.0   36 months
# 3  NaN        NaN    14400.0      14400.0          14400.0   60 months
# 4  NaN        NaN     7000.0       7000.0           7000.0   36 months
#
#   int_rate  installment grade sub_grade       ...        \
# 0   10.49%       162.49     B        B2       ...
# 1    5.32%       391.50     A        A1       ...
# 2    7.99%       563.98     A        A5       ...
# 3    7.99%       291.92     A        A5       ...
# 4    5.32%       210.81     A        A1       ...
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#   disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 0                Cash                     N                       NaN
# 1                Cash                     N                       NaN
# 2                Cash                     N                       NaN
# 3                Cash                     N                       NaN
# 4                Cash                     N                       NaN
#
#   settlement_status settlement_date settlement_amount  settlement_percentage  \
# 0               NaN             NaN               NaN                    NaN
# 1               NaN             NaN               NaN                    NaN
# 2               NaN             NaN               NaN                    NaN
# 3               NaN             NaN               NaN                    NaN
# 4               NaN             NaN               NaN                    NaN
#
#   settlement_term
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 145 columns]
#  TAIL
#                                                       id  member_id  \
# 103543                                               NaN        NaN
# 103544                                               NaN        NaN
# 103545                                               NaN        NaN
# 103546  Total amount funded in policy code 1: 1465324575        NaN
# 103547   Total amount funded in policy code 2: 521953170        NaN
#
#         loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 103543    40000.0      40000.0          40000.0   60 months   10.49%
# 103544    24000.0      24000.0          24000.0   60 months   14.49%
# 103545    14000.0      14000.0          14000.0   60 months   14.49%
# 103546        NaN          NaN              NaN         NaN      NaN
# 103547        NaN          NaN              NaN         NaN      NaN
#
#         installment grade sub_grade       ...        \
# 103543       859.56     B        B3       ...
# 103544       564.56     C        C4       ...
# 103545       329.33     C        C4       ...
# 103546          NaN   NaN       NaN       ...
# 103547          NaN   NaN       NaN       ...
#
#        hardship_payoff_balance_amount hardship_last_payment_amount  \
# 103543                            NaN                          NaN
# 103544                            NaN                          NaN
# 103545                            NaN                          NaN
# 103546                            NaN                          NaN
# 103547                            NaN                          NaN
#
#        disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 103543                Cash                     N                       NaN
# 103544                Cash                     N                       NaN
# 103545                Cash                     N                       NaN
# 103546                 NaN                   NaN                       NaN
# 103547                 NaN                   NaN                       NaN
#
#        settlement_status settlement_date settlement_amount  \
# 103543               NaN             NaN               NaN
# 103544               NaN             NaN               NaN
# 103545               NaN             NaN               NaN
# 103546               NaN             NaN               NaN
# 103547               NaN             NaN               NaN
#
#         settlement_percentage settlement_term
# 103543                    NaN             NaN
# 103544                    NaN             NaN
# 103545                    NaN             NaN
# 103546                    NaN             NaN
# 103547                    NaN             NaN
#
# [5 rows x 145 columns]

# %% [markdown]
# There are a few data descriptors at the end of the files than need to be remove.

# %%
data_2016 = data_2016.sort_values(by = 'id',na_position = 'first', ascending=True)
display(data_2016.tail(10))
# Out:
#                                                       id  member_id  \
# 103538                                               NaN        NaN
# 103539                                               NaN        NaN
# 103540                                               NaN        NaN
# 103541                                               NaN        NaN
# 103542                                               NaN        NaN
# 103543                                               NaN        NaN
# 103544                                               NaN        NaN
# 103545                                               NaN        NaN
# 103546  Total amount funded in policy code 1: 1465324575        NaN
# 103547   Total amount funded in policy code 2: 521953170        NaN
#
#         loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 103538    29400.0      29400.0          29400.0   60 months   13.99%
# 103539    16000.0      16000.0          16000.0   60 months   12.79%
# 103540    24000.0      24000.0          24000.0   60 months   10.49%
# 103541    24000.0      24000.0          24000.0   60 months   12.79%
# 103542    24000.0      24000.0          24000.0   60 months   10.49%
# 103543    40000.0      40000.0          40000.0   60 months   10.49%
# 103544    24000.0      24000.0          24000.0   60 months   14.49%
# 103545    14000.0      14000.0          14000.0   60 months   14.49%
# 103546        NaN          NaN              NaN         NaN      NaN
# 103547        NaN          NaN              NaN         NaN      NaN
#
#         installment grade sub_grade       ...        \
# 103538       683.94     C        C3       ...
# 103539       362.34     C        C1       ...
# 103540       515.74     B        B3       ...
# 103541       543.50     C        C1       ...
# 103542       515.74     B        B3       ...
# 103543       859.56     B        B3       ...
# 103544       564.56     C        C4       ...
# 103545       329.33     C        C4       ...
# 103546          NaN   NaN       NaN       ...
# 103547          NaN   NaN       NaN       ...
#
#        hardship_payoff_balance_amount hardship_last_payment_amount  \
# 103538                            NaN                          NaN
# 103539                            NaN                          NaN
# 103540                            NaN                          NaN
# 103541                            NaN                          NaN
# 103542                            NaN                          NaN
# 103543                            NaN                          NaN
# 103544                            NaN                          NaN
# 103545                            NaN                          NaN
# 103546                            NaN                          NaN
# 103547                            NaN                          NaN
#
#        disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 103538                Cash                     N                       NaN
# 103539                Cash                     N                       NaN
# 103540                Cash                     N                       NaN
# 103541                Cash                     N                       NaN
# 103542                Cash                     N                       NaN
# 103543                Cash                     N                       NaN
# 103544                Cash                     N                       NaN
# 103545                Cash                     N                       NaN
# 103546                 NaN                   NaN                       NaN
# 103547                 NaN                   NaN                       NaN
#
#        settlement_status settlement_date settlement_amount  \
# 103538               NaN             NaN               NaN
# 103539               NaN             NaN               NaN
# 103540               NaN             NaN               NaN
# 103541               NaN             NaN               NaN
# 103542               NaN             NaN               NaN
# 103543               NaN             NaN               NaN
# 103544               NaN             NaN               NaN
# 103545               NaN             NaN               NaN
# 103546               NaN             NaN               NaN
# 103547               NaN             NaN               NaN
#
#         settlement_percentage settlement_term
# 103538                    NaN             NaN
# 103539                    NaN             NaN
# 103540                    NaN             NaN
# 103541                    NaN             NaN
# 103542                    NaN             NaN
# 103543                    NaN             NaN
# 103544                    NaN             NaN
# 103545                    NaN             NaN
# 103546                    NaN             NaN
# 103547                    NaN             NaN
#
# [10 rows x 145 columns]

# %%
print ('The data frame has %d rows (loans) with %d columns' % (data_2016.shape[0], data_2016.shape[1]))
data_2016.drop(data_2016.tail(5).index,inplace=True)
display(data_2016.tail(5))
# Out:
# The data frame has 103548 rows (loans) with 145 columns
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 103538  NaN        NaN    29400.0      29400.0          29400.0   60 months
# 103539  NaN        NaN    16000.0      16000.0          16000.0   60 months
# 103540  NaN        NaN    24000.0      24000.0          24000.0   60 months
# 103541  NaN        NaN    24000.0      24000.0          24000.0   60 months
# 103542  NaN        NaN    24000.0      24000.0          24000.0   60 months
#
#        int_rate  installment grade sub_grade       ...        \
# 103538   13.99%       683.94     C        C3       ...
# 103539   12.79%       362.34     C        C1       ...
# 103540   10.49%       515.74     B        B3       ...
# 103541   12.79%       543.50     C        C1       ...
# 103542   10.49%       515.74     B        B3       ...
#
#        hardship_payoff_balance_amount hardship_last_payment_amount  \
# 103538                            NaN                          NaN
# 103539                            NaN                          NaN
# 103540                            NaN                          NaN
# 103541                            NaN                          NaN
# 103542                            NaN                          NaN
#
#        disbursement_method  debt_settlement_flag debt_settlement_flag_date  \
# 103538                Cash                     N                       NaN
# 103539                Cash                     N                       NaN
# 103540                Cash                     N                       NaN
# 103541                Cash                     N                       NaN
# 103542                Cash                     N                       NaN
#
#        settlement_status settlement_date settlement_amount  \
# 103538               NaN             NaN               NaN
# 103539               NaN             NaN               NaN
# 103540               NaN             NaN               NaN
# 103541               NaN             NaN               NaN
# 103542               NaN             NaN               NaN
#
#         settlement_percentage settlement_term
# 103538                    NaN             NaN
# 103539                    NaN             NaN
# 103540                    NaN             NaN
# 103541                    NaN             NaN
# 103542                    NaN             NaN
#
# [5 rows x 145 columns]

# %% [markdown]
# Remove the columns with only NaN and or with large number of NaN

# %%
pd.DataFrame(data_2016.isnull().sum().sort_values()[data_2016.isnull().sum().sort_values()<10])
# Out:
#                             0
# total_cu_tl                 0
# open_rv_12m                 0
# num_tl_90g_dpd_24m          0
# total_bal_il                0
# num_tl_op_past_12m          0
# open_il_24m                 0
# open_il_12m                 0
# open_act_il                 0
# open_acc_6m                 0
# open_rv_24m                 0
# tot_cur_bal                 0
# acc_now_delinq              0
# pct_tl_nvr_dlq              0
# pub_rec_bankruptcies        0
# application_type            0
# policy_code                 0
# tax_liens                   0
# collections_12_mths_ex_med  0
# num_bc_tl                   0
# tot_coll_amt                0
# last_pymnt_amnt             0
# max_bal_bc                  0
# inq_fi                      0
# num_bc_sats                 0
# num_actv_rev_tl             0
# num_actv_bc_tl              0
# num_accts_ever_120_pd       0
# num_op_rev_tl               0
# num_rev_accts               0
# num_rev_tl_bal_gt_0         0
# ...                        ..
# installment                 0
# int_rate                    0
# term                        0
# funded_amnt_inv             0
# funded_amnt                 0
# loan_amnt                   0
# hardship_flag               0
# disbursement_method         0
# zip_code                    0
# num_il_tl                   0
# total_acc                   0
# out_prncp_inv               0
# addr_state                  0
# total_pymnt                 0
# revol_bal                   0
# pub_rec                     0
# total_pymnt_inv             0
# initial_list_status         0
# total_rec_prncp             0
# total_bal_ex_mort           0
# total_bc_limit              0
# inq_last_6mths              0
# earliest_cr_line            0
# delinq_2yrs                 0
# total_rec_int               0
# open_acc                    0
# out_prncp                   0
# title                       2
# last_credit_pull_d          4
# all_util                    6
#
# [88 rows x 1 columns]

# %%
data_2016 = data_2016.dropna(axis=1, how='all')
data_2016.shape
# Out:
# (103543, 131)

# %%
def df_col_low_nan(df_data, min_nan): 
    # Returns a df with columns with less nan than min_nan
    use_col = pd.DataFrame(df_data.isnull().sum().sort_values()[df_data.isnull().sum().sort_values()<min_nan])
    use_col.reset_index(drop = False, inplace=True)
    use_col.columns = (['col_name','num_NaN'])
    new_data = pd.DataFrame()
    for i in range(0,len(use_col.col_name)):
        df = df_data[use_col.col_name[i]]
        new_data = pd.concat([new_data, df], axis=1)
    return new_data

# %%
data_2016 = df_col_low_nan(data_2016, 10)
data_2016.shape
# Out:
# (103543, 88)

# %%
n_loan_df = pd.read_csv('data_files/loans_2017_clean.csv')
print(len(n_loan_df.columns))
n_loan_df.columns
# Out:
# 28
# Index(['loan_amnt', 'hardship_flag', 'revol_bal', 'out_prncp', 'total_pymnt',
#        'disbursement_method', 'total_pymnt_inv', 'total_rec_late_fee',
#        'recoveries', 'collection_recovery_fee', 'last_pymnt_amnt',
#        'application_type', 'total_rec_int', 'addr_state', 'total_rec_prncp',
#        'verification_status', 'term', 'int_rate', 'grade', 'emp_length',
#        'home_ownership', 'purpose', 'issue_d', 'loan_status', 'pymnt_plan',
#        'debt_settlement_flag', 'annual_inc', 'last_credit_pull_d'],
#       dtype='object')

# %%
new_df = pd.DataFrame()
for col in n_loan_df.columns:
    df = data_2016[col]
    new_df = pd.concat([new_df, df], axis=1)
print(new_df.shape)
n_loan_df = new_df
# Out:
# (103543, 28)

# %% [markdown]
# ## Cleaning target feature (loan_status)

# %%
n_loan_df = new_df

# %%
n_loan_df.loan_status.unique()
# Out:
# array(['Current', 'Fully Paid', 'Late (16-30 days)', 'Charged Off',
#        'Late (31-120 days)', 'In Grace Period', 'Default'], dtype=object)

# %%
# Removing fully paid loans
#n_loan_df = n_loan_df[n_loan_df.loan_status.str.contains('Current')==False]

# Collapsing all but Fully Paid into Problem Loan
n_loan_df.loan_status = n_loan_df.loan_status.str.replace(r'(^.*Paid$)', 'Fully Paid')
n_loan_df.loan_status = n_loan_df.loan_status.str.replace(r'(^.*Charged Off$)', 'Charged Off')
n_loan_df.loan_status = n_loan_df.loan_status.str.replace(r'(^Late.*$)', 'Late')
n_loan_df.loan_status = n_loan_df.loan_status.str.replace(r'(Late)|(Charged Off)|(In Grace Period)|(Default)', 
                                                          'Problem Loan')
n_loan_df.loan_status.unique()
# Out:
# array(['Current', 'Fully Paid', 'Problem Loan'], dtype=object)

# %%
# Removing fully paid loans
n_loan_df = n_loan_df[n_loan_df.loan_status.str.contains('Current')==False]
n_loan_df.loan_status.unique()
# Out:
# array(['Fully Paid', 'Problem Loan'], dtype=object)

# %% [markdown]
# ## Feature cleaning and selection

# %%
# Custom functiones needed later
def types_of_columns(df):
    # creates two separate dataframes 
    # one with float column names and the other with object column names
    non_num_cols = df.dtypes[df.dtypes == 'object']
    float_cols   = df.dtypes[df.dtypes != 'object']
    return non_num_cols, float_cols

def column_checker (df1, df2, num):
    # df1 dataframe whit the columns
    # df2 dataframe with colum names
    for col in range(0,len(df2)):
        col = df2.index[col]
        values = df1[col].unique()
        if len(values) > num:
           print('\n', col, '\n',len(values),'\n',values)

# %% [markdown]
# Sorting the columns by type

# %%
col_types_original = types_of_columns(n_loan_df)

# %% [markdown]
# ### Non-Numeric Features

# %%
nn_col_list = col_types_original[1]
nn_col_list
# Out:
# loan_amnt                  float64
# revol_bal                  float64
# out_prncp                  float64
# total_pymnt                float64
# total_pymnt_inv            float64
# total_rec_late_fee         float64
# recoveries                 float64
# collection_recovery_fee    float64
# last_pymnt_amnt            float64
# total_rec_int              float64
# total_rec_prncp            float64
# annual_inc                 float64
# dtype: object

# %%
column_checker(n_loan_df, types_of_columns(n_loan_df)[0], 0)
# Out:
#  hardship_flag
#  2
#  ['N' 'Y']
#
#  disbursement_method
#  2
#  ['Cash' 'DirectPay']
#
#  application_type
#  2
#  ['Individual' 'Joint App']
#
#  addr_state
#  49
#  ['KS' 'CT' 'MI' 'FL' 'CO' 'MD' 'TX' 'UT' 'AZ' 'CA' 'NC' 'OR' 'AL' 'WA' 'MA'
#  'IL' 'IN' 'PA' 'MN' 'NY' 'DE' 'WY' 'OH' 'TN' 'VA' 'WI' 'MS' 'GA' 'OK' 'SC'
#  'NJ' 'HI' 'MO' 'NV' 'VT' 'NM' 'AK' 'KY' 'ID' 'RI' 'MT' 'LA' 'AR' 'DC' 'ME'
#  'NE' 'NH' 'SD' 'ND']
#
#  verification_status
#  3
#  ['Source Verified' 'Not Verified' 'Verified']
#
#  term
#  2
#  [' 36 months' ' 60 months']
#
#  int_rate
#  57
#  ['  7.99%' ' 11.44%' ' 13.49%' ' 13.99%' ' 11.49%' '  8.24%' '  7.49%'
#  ' 14.99%' ' 10.49%' ' 12.74%' ' 22.74%' ' 16.99%' ' 24.74%' ' 25.49%'
#  ' 17.99%' ' 19.99%' ' 21.49%' ' 11.39%' ' 15.99%' '  7.24%' ' 26.24%'
#  '  6.99%' ' 23.99%' ' 28.69%' ' 18.99%' '  5.32%' ' 30.89%' ' 29.49%'
#  '  6.00%' ' 29.99%' ' 30.74%' ' 30.99%' ' 30.84%' ' 30.49%' ' 30.79%'
#  ' 30.94%' ' 25.29%' ' 14.49%' ' 15.59%' '  9.49%' ' 12.79%' ' 29.96%'
#  '  8.99%' ' 22.39%' ' 27.79%' ' 24.99%' ' 26.99%' ' 25.69%' ' 24.49%'
#  '  8.59%' '  7.59%' ' 26.49%' ' 10.99%' ' 28.88%' ' 29.67%' ' 28.18%'
#  ' 27.49%']
#
#  grade
#  7
#  ['A' 'B' 'C' 'E' 'D' 'F' 'G']
#
#  emp_length
#  12
#  ['10+ years' '6 years' '9 years' '8 years' '3 years' '< 1 year' '2 years'
#  '1 year' '5 years' 'n/a' '7 years' '4 years']
#
#  home_ownership
#  4
#  ['MORTGAGE' 'RENT' 'OWN' 'ANY']
#
#  purpose
#  12
#  ['credit_card' 'debt_consolidation' 'home_improvement' 'other' 'car'
#  'small_business' 'major_purchase' 'vacation' 'moving' 'medical' 'house'
#  'renewable_energy']
#
#  issue_d
#  3
#  ['Dec-2016' 'Nov-2016' 'Oct-2016']
#
#  loan_status
#  2
#  ['Fully Paid' 'Problem Loan']
#
#  pymnt_plan
#  2
#  ['n' 'y']
#
#  debt_settlement_flag
#  2
#  ['N' 'Y']
#
#  last_credit_pull_d
#  15
#  ['Oct-2017' 'Sep-2017' 'Jun-2017' 'Jul-2017' 'Feb-2017' 'Aug-2017'
#  'Mar-2017' 'Apr-2017' 'May-2017' 'Jan-2017' 'Dec-2016' 'Nov-2017'
#  'Nov-2016' 'Oct-2016' 'Sep-2016']

# %% [markdown]
# #### Dropping columns with repetitive or non-relevant information
#
# zip_code and addr_state have similar information - keeping addr_state
#
# grade and sub_grade also have similar information - keeping grade

# %% [markdown]
# Converting dates and other numbers into actual numeric variables

# %%
# int_rate
n_loan_df.int_rate = n_loan_df.int_rate.str.replace('%', " ").astype(float)

# emp_length
# Removing 2110 rows with n/a in emp_length
n_loan_df = n_loan_df[n_loan_df.emp_length.str.contains('n/a')==False]
# less than one year is now 0
n_loan_df.emp_length = n_loan_df.emp_length.str.replace(r'( years)|( year)|(\+ years)', "").str.replace('< 1','0').astype(float)

# Dates
# issue_d is now delta time since issued
n_loan_df.issue_d = ((max(pd.to_datetime(n_loan_df['issue_d'])) - pd.to_datetime(n_loan_df['issue_d'])).dt.days/365).astype(int)

# last_credit_pull_d is now delta time since last credit check
n_loan_df.last_credit_pull_d = (max(pd.to_datetime(n_loan_df['last_credit_pull_d'])) - pd.to_datetime(n_loan_df['last_credit_pull_d'])).dt.days/365
n_loan_df.last_credit_pull_d = n_loan_df.last_credit_pull_d[n_loan_df.last_credit_pull_d.isnull()==False]
n_loan_df = n_loan_df[n_loan_df.last_credit_pull_d.isnull() == False]
# Out:
# /Users/jpinzon/anaconda/lib/python3.6/site-packages/pandas/core/generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
column_checker(n_loan_df, types_of_columns(n_loan_df)[0], 0)
# Out:
#  hardship_flag
#  2
#  ['N' 'Y']
#
#  disbursement_method
#  2
#  ['Cash' 'DirectPay']
#
#  application_type
#  2
#  ['Individual' 'Joint App']
#
#  addr_state
#  49
#  ['KS' 'CT' 'MI' 'FL' 'CO' 'MD' 'TX' 'UT' 'AZ' 'CA' 'NC' 'OR' 'AL' 'WA' 'MA'
#  'IL' 'IN' 'PA' 'MN' 'NY' 'DE' 'WY' 'OH' 'TN' 'VA' 'MS' 'GA' 'OK' 'SC' 'WI'
#  'NJ' 'HI' 'NV' 'VT' 'NM' 'AK' 'MO' 'KY' 'ID' 'MT' 'LA' 'AR' 'DC' 'ME' 'NE'
#  'NH' 'RI' 'SD' 'ND']
#
#  verification_status
#  3
#  ['Source Verified' 'Not Verified' 'Verified']
#
#  term
#  2
#  [' 36 months' ' 60 months']
#
#  grade
#  7
#  ['A' 'B' 'C' 'E' 'D' 'F' 'G']
#
#  home_ownership
#  4
#  ['MORTGAGE' 'RENT' 'OWN' 'ANY']
#
#  purpose
#  12
#  ['credit_card' 'debt_consolidation' 'home_improvement' 'other' 'car'
#  'small_business' 'vacation' 'major_purchase' 'medical' 'house' 'moving'
#  'renewable_energy']
#
#  loan_status
#  2
#  ['Fully Paid' 'Problem Loan']
#
#  pymnt_plan
#  2
#  ['n' 'y']
#
#  debt_settlement_flag
#  2
#  ['N' 'Y']

# %%
#n_loan_df = pd.read_csv('loans_2017.csv')
n_loan_df.shape
# Out:
# (22171, 28)

# %%
nn_col_list = types_of_columns(n_loan_df)[0].index.drop(['loan_status'])

row = 4
col = 3

fig, axs = pl.subplots(row,col, figsize=(20,30))
fig.subplots_adjust(wspace=0.5, hspace=0.25)

for num, name in enumerate(nn_col_list):
    #print (num, name)
    i = num%row
    j = num%col
    graph = sns.countplot(y = n_loan_df[name], hue=n_loan_df['loan_status'], ax = axs[i,j], linewidth = 1.5)
    graph.set(xlabel=name, ylabel='')

# %%
for col in nn_col_list:
    series = n_loan_df.groupby(col)['loan_status'].count()
    print ('\n',series)
# Out:
#  hardship_flag
# N    21827
# Y      344
# Name: loan_status, dtype: int64
#
#  disbursement_method
# Cash         22165
# DirectPay        6
# Name: loan_status, dtype: int64
#
#  application_type
# Individual    21436
# Joint App       735
# Name: loan_status, dtype: int64
#
#  addr_state
# AK      38
# AL     298
# AR     158
# AZ     565
# CA    3268
# CO     513
# CT     290
# DC      51
# DE      65
# FL    1699
# GA     701
# HI     113
# ID      63
# IL     788
# IN     374
# KS     158
# KY     223
# LA     251
# MA     491
# MD     525
# ME      54
# MI     605
# MN     430
# MO     300
# MS     125
# MT      53
# NC     643
# ND      48
# NE     117
# NH     118
# NJ     732
# NM     116
# NV     308
# NY    1742
# OH     734
# OK     184
# OR     236
# PA     766
# RI      90
# SC     248
# SD      34
# TN     340
# TX    1988
# UT     192
# VA     567
# VT      43
# WA     417
# WI     272
# WY      37
# Name: loan_status, dtype: int64
#
#  verification_status
# Not Verified       5876
# Source Verified    9290
# Verified           7005
# Name: loan_status, dtype: int64
#
#  term
#  36 months    16735
#  60 months     5436
# Name: loan_status, dtype: int64
#
#  grade
# A    2021
# B    5933
# C    7348
# D    4284
# E    1753
# F     632
# G     200
# Name: loan_status, dtype: int64
#
#  home_ownership
# ANY            14
# MORTGAGE    11172
# OWN          2568
# RENT         8417
# Name: loan_status, dtype: int64
#
#  purpose
# car                     213
# credit_card            3835
# debt_consolidation    13006
# home_improvement       1679
# house                   128
# major_purchase          599
# medical                 326
# moving                  205
# other                  1708
# renewable_energy         24
# small_business          265
# vacation                183
# Name: loan_status, dtype: int64
#
#  pymnt_plan
# n    21852
# y      319
# Name: loan_status, dtype: int64
#
#  debt_settlement_flag
# N    22019
# Y      152
# Name: loan_status, dtype: int64

# %% [markdown]
# ### Numeric Features

# %%
num_col_list = types_of_columns(n_loan_df)[1].index

for col in num_col_list:
    length = len(n_loan_df[col].unique())
    print (col, length)
# Out:
# loan_amnt 1186
# revol_bal 15872
# out_prncp 4046
# total_pymnt 21781
# total_pymnt_inv 21687
# total_rec_late_fee 604
# recoveries 535
# collection_recovery_fee 541
# last_pymnt_amnt 18565
# total_rec_int 20651
# total_rec_prncp 7347
# int_rate 57
# emp_length 11
# issue_d 1
# annual_inc 2271
# last_credit_pull_d 15

# %%
num_col_list = types_of_columns(n_loan_df)[1].index

cor_df = pd.DataFrame()
for i in range(0,len(num_col_list)):
    cor_df = pd.concat([cor_df, n_loan_df[num_col_list[i]]],axis=1)

# %%
f, ax = pl.subplots(figsize=(10, 8))
corr = cor_df.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(250, 15, as_cmap=True),
            square=True, ax=ax, annot=True, vmin=0, vmax=1, linewidths=2, xticklabels=1, yticklabels=True)

# %%
row1 = 4
col1 = 4

fig, axs = pl.subplots(row1,col1, figsize=(20,15))
fig.subplots_adjust(wspace=0.5, hspace=0.25)

for num, name in enumerate(num_col_list):
    i = num//row1
    j = num%col1
    graph = sns.boxplot(y = n_loan_df[name], ax = axs[i,j], linewidth = 1.5)
    graph.set(xlabel=name, ylabel='')

# %%
n_loan_df = n_loan_df[n_loan_df.annual_inc.isnull()==False]

# %% [markdown]
# Removing outgroups

# %%
n_loans = n_loan_df.reset_index(drop=True)
# ADAPTE FROM CUSTOMER SEGMENTATION PROJECT
outliers_all = np.array([], dtype='int64')
for column in types_of_columns(n_loans)[1].index:
    Q1 = np.percentile(n_loans[column], 25)
    Q3 = np.percentile(n_loans[column], 75)
    step = (Q3 - Q1)*2
    out_list_feat=list(n_loans[~((n_loans[column] >= Q1 - step) & (n_loans[column] <= Q3 + step))].index)
    outliers_all = np.append(outliers_all, out_list_feat)

from collections import Counter
out_count = Counter(outliers_all)
out_customer =[]
for customer, count in out_count.items():
    if count > 1:
        out_customer.append(customer.astype(int))
outliers  = list(sorted(out_customer))

print("%d outliers found in more than one feature will be remove" % len(outliers))

n_loan_no_out = n_loans.drop(n_loans.index[outliers])
    
print(n_loan_df.shape, n_loan_no_out.shape)
# Out:
# 2166 outliers found in more than one feature will be remove
# (22171, 28) (20005, 28)

# %%
row1 = 4
col1 = 4

fig, axs = pl.subplots(row1,col1, figsize=(20,15))
fig.subplots_adjust(wspace=0.5, hspace=0.25)

for num, name in enumerate(num_col_list):
    i = num//row1
    j = num%col1
    graph = sns.boxplot(y = n_loan_no_out[name], ax = axs[i,j], linewidth = 1.5)
    graph.set(xlabel=name, ylabel='')

# %% [markdown]
# Encoding categorical columns

# %%
n_loan_no_out.describe()
# Out:
#           loan_amnt      revol_bal     out_prncp   total_pymnt  \
# count  20005.000000   20005.000000  20005.000000  20005.000000
# mean   13730.401150   14067.530617   1846.497848  11437.501772
# std     8772.652652   15832.011124   4997.831977   9524.770693
# min     1000.000000       0.000000      0.000000      0.000000
# 25%     7000.000000    5434.000000      0.000000   3848.250000
# 50%    12000.000000   10247.000000      0.000000   8608.630725
# 75%    19250.000000   17889.000000      0.000000  16367.429021
# max    40000.000000  477970.000000  36716.940000  41077.541813
#
#        total_pymnt_inv  total_rec_late_fee    recoveries  \
# count     20005.000000        20005.000000  20005.000000
# mean      11433.225143            0.491094      1.171669
# std        9522.050195            4.307834    165.719742
# min           0.000000            0.000000      0.000000
# 25%        3847.900000            0.000000      0.000000
# 50%        8606.390000            0.000000      0.000000
# 75%       16365.840000            0.000000      0.000000
# max       41000.920000          154.860000  23439.240000
#
#        collection_recovery_fee  last_pymnt_amnt  total_rec_int  \
# count                  20005.0     20005.000000   20005.000000
# mean                       0.0      8411.390145     999.173784
# std                        0.0      8794.373054     970.939466
# min                        0.0         0.000000       0.000000
# 25%                        0.0       649.960000     296.870000
# 50%                        0.0      5828.110000     689.850000
# 75%                        0.0     13268.560000    1395.800000
# max                        0.0     40880.360000    9181.670000
#
#        total_rec_prncp      int_rate    emp_length  issue_d    annual_inc  \
# count     20005.000000  20005.000000  20005.000000  20005.0  2.000500e+04
# mean      10436.665221     14.573761      6.015396      0.0  7.841395e+04
# std        9114.401200      5.287224      3.720080      0.0  6.398435e+04
# min           0.000000      5.320000      0.000000      0.0  2.400000e+03
# 25%        2800.000000     11.390000      2.000000      0.0  5.000000e+04
# 50%        8000.000000     13.490000      6.000000      0.0  7.000000e+04
# 75%       15000.000000     17.990000     10.000000      0.0  9.500000e+04
# max       40000.000000     30.990000     10.000000      0.0  6.500000e+06
#
#        last_credit_pull_d
# count        20005.000000
# mean             0.257233
# std              0.242047
# min              0.000000
# 25%              0.084932
# 50%              0.167123
# 75%              0.336986
# max              1.167123

# %%
for col in (nn_col_list):
    n_loan_no_out[col]=l_encoder.fit_transform(n_loan_no_out[col])
n_loan_no_out.head()
# Out:
#    loan_amnt  hardship_flag  revol_bal  out_prncp  total_pymnt  \
# 0     8000.0              0     5938.0        0.0  8342.110922
# 1     5000.0              0    10377.0        0.0  5267.905588
# 2     8400.0              0    19885.0        0.0  9023.279968
# 3     7175.0              0     3383.0        0.0  7536.773657
# 4     6000.0              0     4662.0        0.0  6334.533998
#
#    disbursement_method  total_pymnt_inv  total_rec_late_fee  recoveries  \
# 0                    0          8342.11                 0.0         0.0
# 1                    0          5267.91                 0.0         0.0
# 2                    0          9023.28                 0.0         0.0
# 3                    0          7536.77                 0.0         0.0
# 4                    0          6334.53                 0.0         0.0
#
#    collection_recovery_fee         ...          grade  emp_length  \
# 0                      0.0         ...              0        10.0
# 1                      0.0         ...              1        10.0
# 2                      0.0         ...              1        10.0
# 3                      0.0         ...              2        10.0
# 4                      0.0         ...              2        10.0
#
#    home_ownership  purpose  issue_d  loan_status  pymnt_plan  \
# 0               1        1        0   Fully Paid           0
# 1               3        1        0   Fully Paid           0
# 2               1        1        0   Fully Paid           0
# 3               1        2        0   Fully Paid           0
# 4               3        1        0   Fully Paid           0
#
#    debt_settlement_flag  annual_inc  last_credit_pull_d
# 0                     0     57000.0            0.084932
# 1                     0     60000.0            0.084932
# 2                     0     70000.0            0.167123
# 3                     0     65000.0            0.084932
# 4                     0     34278.0            0.419178
#
# [5 rows x 28 columns]

# %%
n_loan_no_out.loan_status = l_encoder.fit_transform(n_loan_no_out.loan_status)
n_loan_no_out.loan_status.unique()
# Out:
# array([0, 1])

# %%
print(n_loan_no_out.shape)
n_loan_no_out.head(10)
# Out:
# (20005, 28)
#     loan_amnt  hardship_flag  revol_bal  out_prncp   total_pymnt  \
# 0      8000.0              0     5938.0        0.0   8342.110922
# 1      5000.0              0    10377.0        0.0   5267.905588
# 2      8400.0              0    19885.0        0.0   9023.279968
# 3      7175.0              0     3383.0        0.0   7536.773657
# 4      6000.0              0     4662.0        0.0   6334.533998
# 6     10000.0              0    14235.0        0.0  10587.252371
# 7      2000.0              0     6288.0        0.0   2035.976448
# 8     12000.0              0     5206.0        0.0  12899.775532
# 9      3500.0              0     3214.0        0.0   3537.607458
# 10    10000.0              0   128691.0        0.0  10490.860871
#
#     disbursement_method  total_pymnt_inv  total_rec_late_fee  recoveries  \
# 0                     0          8342.11                 0.0         0.0
# 1                     0          5267.91                 0.0         0.0
# 2                     0          9023.28                 0.0         0.0
# 3                     0          7536.77                 0.0         0.0
# 4                     0          6334.53                 0.0         0.0
# 6                     0         10587.25                 0.0         0.0
# 7                     0          2035.98                 0.0         0.0
# 8                     0         12899.78                20.8         0.0
# 9                     0          3537.61                 0.0         0.0
# 10                    0         10490.86                 0.0         0.0
#
#     collection_recovery_fee         ...          grade  emp_length  \
# 0                       0.0         ...              0        10.0
# 1                       0.0         ...              1        10.0
# 2                       0.0         ...              1        10.0
# 3                       0.0         ...              2        10.0
# 4                       0.0         ...              2        10.0
# 6                       0.0         ...              1         9.0
# 7                       0.0         ...              0         6.0
# 8                       0.0         ...              2        10.0
# 9                       0.0         ...              0         8.0
# 10                      0.0         ...              1        10.0
#
#     home_ownership  purpose  issue_d  loan_status  pymnt_plan  \
# 0                1        1        0            0           0
# 1                3        1        0            0           0
# 2                1        1        0            0           0
# 3                1        2        0            0           0
# 4                3        1        0            0           0
# 6                3        2        0            0           0
# 7                3        1        0            0           0
# 8                1        2        0            0           0
# 9                1        2        0            0           0
# 10               1        1        0            0           0
#
#     debt_settlement_flag  annual_inc  last_credit_pull_d
# 0                      0     57000.0            0.084932
# 1                      0     60000.0            0.084932
# 2                      0     70000.0            0.167123
# 3                      0     65000.0            0.084932
# 4                      0     34278.0            0.419178
# 6                      0     40000.0            0.084932
# 7                      0     42000.0            0.084932
# 8                      0     68000.0            0.336986
# 9                      0    145000.0            0.084932
# 10                     0     99000.0            0.084932
#
# [10 rows x 28 columns]

# %% [markdown]
# ### Spliting the data for the model
#
# Spliting into features and target

# %%
target = n_loan_no_out.loan_status.values
features = n_loan_no_out.drop(['loan_status'], axis=1).values
print ('Loans original data %d, target: %d, features: %d' % (n_loan_no_out.shape[0], target.shape[0], features.shape[0]))
# Out:
# Loans original data 20005, target: 20005, features: 20005

# %% [markdown]
# ### Building an initial model

# %%
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=pl.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)

    pl.imshow(cm, interpolation='nearest', cmap=cmap)
    pl.title(title)
    pl.colorbar()
    tick_marks = np.arange(len(classes))
    pl.xticks(tick_marks, classes, rotation=45)
    pl.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        pl.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    pl.tight_layout()
    pl.ylabel('True label')
    pl.xlabel('Predicted label')

# %% [markdown]
# # USING TRAIN, VALIDATION, TEST

# %%
from keras.models import load_model
classifier = load_model('data_files/classifier_opt.h5')
# Out:
# Using TensorFlow backend.

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_2016 = sc.fit_transform(features)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation

# %%
# Predicting on the test set 
pred_2016 = classifier.predict(X_2016)
pred_2016 = (pred_2016 > 0.5)

# %%
from sklearn.metrics import confusion_matrix
cnf_matrix = confusion_matrix(target, pred_2016, labels=[0, 1])
cnf_matrix
# Out:
# array([[14731,     2],
#        [  491,  4781]])

# %%
pl.figure()
plot_confusion_matrix(cnf_matrix, classes=n_loan_no_out.loan_status.unique(),
                      cmap=pl.cm.Reds, normalize=False)
# Out:
# Confusion matrix, without normalization

# %%
from sklearn.metrics import f1_score
f1_score(target, pred_2016.round(), average='binary')
# Out:
# 0.95096966683242168

# %%
loss, accuracy = classifier.evaluate(X_2016, target,batch_size=128, verbose=0)
print("Accuracy = {:.4f}%, Loss = {:.4f}".format(accuracy* 100, loss))
# Out:
# Accuracy = 97.5356%, Loss = 0.1552
